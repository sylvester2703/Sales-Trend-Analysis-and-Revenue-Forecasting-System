# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\Sales trend and revenue forecasting\cleaned_walmart_sales_v2.csv")
print(df.head())
print(df.info())
# Out:
#    id  Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0 NaN    999   999  2026-12-25     9999999.0       True         50.0
#
#    Fuel_Price    CPI  Unemployment Type     Size  created_at
# 0        10.0  500.0           1.0    Z  9999999         NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            0 non-null      float64
#  1   Store         1 non-null      int64
#  2   Dept          1 non-null      int64
#  3   Date          1 non-null      object
#  4   Weekly_Sales  1 non-null      float64
#  5   IsHoliday     1 non-null      bool
#  6   Temperature   1 non-null      float64
#  7   Fuel_Price    1 non-null      float64
#  8   CPI           1 non-null      float64
#  9   Unemployment  1 non-null      float64
#  10  Type          1 non-null      object
#  11  Size          1 non-null      int64
#  12  created_at    0 non-null      float64
# dtypes: bool(1), float64(7), int64(3), object(2)
# memory usage: 229.0+ bytes
# None
